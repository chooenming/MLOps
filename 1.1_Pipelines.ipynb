# %% [markdown]
# Install ZenML and sklearn integration. Then, restart the kernel of the notebook

# %%
# %pip install "zenml[server]"
# !zenml integration install sklearn -y
# %pip uninstall pyparsing==2.4.2 -y

import IPython

# automatically restart kernel
IPython.Application.instance().kernel.do_shutdown(restart=True)
# Out:
# Requirement already satisfied: zenml[server] in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.61.0)
# Requirement already satisfied: Jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (3.1.3)
# Requirement already satisfied: alembic<1.9.0,>=1.8.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (1.8.1)
# Requirement already satisfied: bcrypt==4.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (4.0.1)
# Requirement already satisfied: click<8.1.4,>=8.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (8.1.3)
# Requirement already satisfied: click-params<0.4.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (0.3.0)
# Requirement already satisfied: cloudpickle<3,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (2.2.1)
# Requirement already satisfied: distro<2.0.0,>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (1.9.0)
# Requirement already satisfied: docker<6.2.0,>=6.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (6.1.3)
# Requirement already satisfied: fastapi<=0.110,>=0.100 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (0.110.0)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.18 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (3.1.43)
# Requirement already satisfied: httplib2<0.20,>=0.19.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (0.19.1)
# Requirement already satisfied: ipinfo>=4.4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (5.0.1)
# Requirement already satisfied: numpy<2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (1.26.0)
# Requirement already satisfied: orjson<3.11.0,>=3.10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (3.10.6)
# Requirement already satisfied: pandas>=1.1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (2.1.1)
# Requirement already satisfied: passlib<1.8.0,>=1.7.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from passlib[bcrypt]<1.8.0,>=1.7.4->zenml[server]) (1.7.4)
# Requirement already satisfied: psutil>=5.0.0 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from zenml[server]) (5.9.5)
# Requirement already satisfied: pydantic<2.8,>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (2.7.4)
# Requirement already satisfied: pydantic-settings<2.3.0,>=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (2.2.1)
# Requirement already satisfied: pyjwt==2.7.* in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyjwt[crypto]==2.7.*; extra == "server"->zenml[server]) (2.7.0)
# Requirement already satisfied: pymysql<1.2.0,>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (1.1.1)
# Requirement already satisfied: pyparsing>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (2.4.7)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.1 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from zenml[server]) (2.8.2)
# Requirement already satisfied: python-multipart<0.1.0,>=0.0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (0.0.9)
# Requirement already satisfied: pyyaml>=6.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (6.0.1)
# Requirement already satisfied: requests<2.32.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (2.31.0)
# Requirement already satisfied: rich>=12.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich[jupyter]>=12.0.0->zenml[server]) (13.7.1)
# Requirement already satisfied: secure<0.4.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (0.3.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (2.0.31)
# Requirement already satisfied: sqlalchemy_utils in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (0.41.2)
# Requirement already satisfied: sqlmodel==0.0.18 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from zenml[server]) (0.0.18)
# Requirement already satisfied: uvicorn>=0.17.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from uvicorn[standard]>=0.17.5; extra == "server"->zenml[server]) (0.30.1)
# Requirement already satisfied: cryptography>=3.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyjwt[crypto]==2.7.*; extra == "server"->zenml[server]) (42.0.8)
# Requirement already satisfied: Mako in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from alembic<1.9.0,>=1.8.1->zenml[server]) (1.3.5)
# Requirement already satisfied: validators<0.19,>=0.18 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from click-params<0.4.0,>=0.3.0->zenml[server]) (0.18.2)
# Requirement already satisfied: packaging>=14.0 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from docker<6.2.0,>=6.1.0->zenml[server]) (23.1)
# Requirement already satisfied: urllib3>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from docker<6.2.0,>=6.1.0->zenml[server]) (2.2.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from docker<6.2.0,>=6.1.0->zenml[server]) (1.8.0)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fastapi<=0.110,>=0.100->zenml[server]) (0.36.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fastapi<=0.110,>=0.100->zenml[server]) (4.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gitpython<4.0.0,>=3.1.18->zenml[server]) (4.0.11)
# Requirement already satisfied: cachetools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipinfo>=4.4.3->zenml[server]) (5.3.2)
# Requirement already satisfied: aiohttp<=4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipinfo>=4.4.3->zenml[server]) (3.9.5)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=1.1.5->zenml[server]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=1.1.5->zenml[server]) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<2.8,>=2.7->zenml[server]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<2.8,>=2.7->zenml[server]) (2.18.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic-settings<2.3.0,>=2.2.1->zenml[server]) (1.0.1)
# Requirement already satisfied: six>=1.5 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from python-dateutil<3.0.0,>=2.8.1->zenml[server]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<2.32.0->zenml[server]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<2.32.0->zenml[server]) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<2.32.0->zenml[server]) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich>=12.0.0->rich[jupyter]>=12.0.0->zenml[server]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from rich>=12.0.0->rich[jupyter]>=12.0.0->zenml[server]) (2.16.1)
# Requirement already satisfied: ipywidgets<9,>=7.5.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich[jupyter]>=12.0.0->zenml[server]) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from uvicorn>=0.17.5->uvicorn[standard]>=0.17.5; extra == "server"->zenml[server]) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from uvicorn[standard]>=0.17.5; extra == "server"->zenml[server]) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from uvicorn[standard]>=0.17.5; extra == "server"->zenml[server]) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from uvicorn[standard]>=0.17.5; extra == "server"->zenml[server]) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from uvicorn[standard]>=0.17.5; extra == "server"->zenml[server]) (12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from Jinja2->zenml[server]) (2.1.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (1.9.4)
# Requirement already satisfied: cffi>=1.12 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from cryptography>=3.4.0->pyjwt[crypto]==2.7.*; extra == "server"->zenml[server]) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.18->zenml[server]) (5.0.1)
# Requirement already satisfied: comm>=0.1.3 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (8.16.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (5.10.1)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (3.0.11)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->rich[jupyter]>=12.0.0->zenml[server]) (0.1.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from starlette<0.37.0,>=0.36.3->fastapi<=0.110,>=0.100->zenml[server]) (4.4.0)
# Requirement already satisfied: decorator>=3.4.0 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from validators<0.19,>=0.18->click-params<0.4.0,>=0.3.0->zenml[server]) (5.1.1)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi<=0.110,>=0.100->zenml[server]) (1.3.1)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]==2.7.*; extra == "server"->zenml[server]) (2.22)
# Requirement already satisfied: backcall in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.19.0)
# Requirement already satisfied: matplotlib-inline in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (3.0.39)
# Requirement already satisfied: stack-data in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (4.8.0)
# Requirement already satisfied: appnope in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.2.8)
# Requirement already satisfied: executing>=1.2.0 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (2.0.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (2.4.0)
# Requirement already satisfied: pure-eval in /Users/chooenming/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.2.2)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ⠼ Installing integrations.....
# Found existing installation: pyparsing 2.4.7
# Uninstalling pyparsing-2.4.7:
#   Successfully uninstalled pyparsing-2.4.7
# Note: you may need to restart the kernel to use updated packages.
# {'status': 'ok', 'restart': True}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # ZenML Setup

# %%
# start with a fresh ML stack
# !rm -rf .zen
# !zenml init
# Out:
# Initializing the ZenML global configuration version to 0.61.0
# Creating database tables
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# Creating default workspace 'default' ...
# Creating default stack in workspace default...
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# Setting the global active workspace to 'default'.
# Setting the global active stack to default.
# Setting the repo active workspace to 'default'.
# Setting the repo active stack to default.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠧ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠴ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠦ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠇ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠏ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠋ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠙ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠹ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠸ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# Reloading configuration file /Users/chooenming/Desktop/MLOps/.zen/config.yaml
# ZenML repository initialized at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
# ⠼ Initializing ZenML repository at /Users/chooenming/Desktop/MLOps.
#
# The local active stack was initialized to 'default'. This local configuration
# will only take effect when you're running ZenML from the initialized repository
# root, or from a subdirectory. For more information on repositories and
# configurations, please visit
# https://docs.zenml.io/user-guide/starter-guide/understand-stacks.

# %% [markdown]
# # Example Experimentation ML Code

# %%
import numpy as np
from sklearn.base import ClassifierMixin
from sklearn.svm import SVC
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

# %%
def train_test() -> None:
    """
    Train and test a Scikit-learn SVC classifier on digits
    """
    digits = load_digits()
    data = digits.images.reshape((len(digits.images), -1))
    X_train, X_test, y_train, y_test = train_test_split(
        data, digits.target, test_size=0.2, shuffle=False
    )
    model = SVC(gamma=0.001)
    model.fit(X_train, y_train)
    test_acc = model.score(X_test, y_test)
    print(f"Test accuracy: {test_acc}")

# %%
train_test()
# Out:
# Test accuracy: 0.9583333333333334

# %% [markdown]
# # Turning experiments into ML pipelines with ZenML

# %%
from zenml import step
from typing_extensions import Annotated
import pandas as pd
from typing import Tuple

# %%
# importer() takes nothing into the args, but return Tuple as mentioned
# have to mention return what type as will be used in the next step
@step
def importer() -> Tuple[
    Annotated[np.ndarray, "X_train"],
    Annotated[np.ndarray, "X_test"],
    Annotated[np.ndarray, "y_train"],
    Annotated[np.ndarray, "y_test"],
]:
    """
    Load the digits dataset as numpy arrays
    """
    digits = load_digits()
    data = digits.images.reshape((len(digits.images), -1))
    X_train, X_test, y_train, y_test = train_test_split(
        data, digits.target, test_size=0.2, shuffle=False
    )
    
    return X_train, X_test, y_train, y_test


# svc_trainer takes X_train and y_train in np.ndarray and return classifier
@step
def svc_trainer(
    X_train: np.ndarray,
    y_train: np.ndarray,
) -> ClassifierMixin:
    """
    Train an sklearn SVC classifier
    """
    model = SVC(gamma=0.001)
    model.fit(X_train, y_train)
    
    return model


@step
def evaluator(
    X_test: np.ndarray,
    y_test: np.ndarray,
    model: ClassifierMixin,
) -> float:
    """
    Calculate the test set accuracy of an sklearn model
    """
    test_acc = model.score(X_test, y_test)
    print(f"Test accuracy: {test_acc}")
    
    return test_acc

# %% [markdown]
# use @pipeline decorator to connect all steps into an ML pipeline
#
# <br>Pipeline does not depend on the concrete step functions defined above; it merely establishes a recipe for how data moves through the steps. This means we can replace steps as we wish, e.g. to run the same pipeline with different models to compare the performances

# %%
from zenml import pipeline

@pipeline
def digits_pipeline():
    """
    Links all the steps together into a pipeline
    """
    X_train, X_test, y_train, y_test = importer()
    model = svc_trainer(X_train=X_train, y_train=y_train)
    evaluator(X_test=X_test, y_test=y_test, model=model)

# %% [markdown]
# # Running ZenML Pipelines
# initialise pipeline with concrete step functions and call the `run()` method to run it

# %%
digits_svc_pipeline = digits_pipeline()
#digits_svc_pipeline.run(unlisted=True)
# Out:
# Initiating a new run for the pipeline: digits_pipeline.
# Registered new version: (version 1).
# Executing a new run.
# Using user: default
# Using stack: default
#   artifact_store: default
#   orchestrator: default
# You can visualize your pipeline runs in the ZenML Dashboard. In order to try it locally, please run zenml up.
# Step importer has started.
# Skipping visualization of numpy array because matplotlib is not installed. To install matplotlib, run pip install matplotlib.
# Skipping visualization of numpy array because matplotlib is not installed. To install matplotlib, run pip install matplotlib.
# Step importer has finished in 0.530s.
# Step importer completed successfully.
# Step svc_trainer has started.
# Step svc_trainer has finished in 0.138s.
# Step svc_trainer completed successfully.
# Step evaluator has started.
# Test accuracy: 0.9583333333333334
# Step evaluator has finished in 0.545s.
# Step evaluator completed successfully.
# Pipeline run has finished in 1.306s.

# %% [markdown]
# visualise the pipeline run in ZenML dashboard
# <br>log in with username `default` and empty password, and navigate to the "Runs" tab in the "Pipelines" section

# %%
import os
from zenml.environment import Environment

def start_zenml_dashboard(port=8237):
    os.environ['OBJC_DISABLE_INITIALIZE_FORK_SAFETY'] = 'YES'
    
    if Environment.in_google_colab():
        from pyngrok import ngrok

        public_url = ngrok.connect(port)
        print(f"Ngrok tunnel available at: {public_url}")
        os.system(f'zenml up --blocking --port {port}')
    
    else:
        os.system(f'zenml up --port {port}')

if __name__ == "__main__":
    start_zenml_dashboard()
